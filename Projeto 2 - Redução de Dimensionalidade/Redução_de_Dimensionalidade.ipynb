# %% [markdown]
# ## Redução de Dimensionalidade em Imagens para Redes Neurais
#
# Desafio de projeto
#
# Autor: Israel de Castro Evangelista
#
# Objetivo: Realizar a implementação em Python para transformar uma imagem colorida para níveis de cinza (0 a 255) e para binarizada (0 e 255), preto e branco.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img = mpimg.imread("/content/drive/MyDrive/Projetos/Projeto DIO - Redução de features/Eu_e_minha_esposa.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
#Convertendo imagem em tons de cinza
img = np.dot(img[...,:3], [0.2989, 0.5870, 0.1140])

# %%
#mostrando imagem em tons de cinza
plt.imshow(img, cmap = plt.get_cmap(name = 'gray'))

# %%
#Salvando imagem em tons de cinza
mpimg.imsave("eu_e_minha_esposa_cinza.jpg", img)

# %%
#convertendo a imagem para binário
#pixels com valores acima de 90 serão convertidos para 1, o resto fica em 0
eu_e_minha_esposa_binario = 1 * (img > 90)

#Mostrando a imagem binária
plt.imshow(eu_e_minha_esposa_binario, cmap = plt.get_cmap(name = 'gray'))
